Houston</td><td>2025-01-01T20:00:00.000Z</td><td>0</td></tr><tr><td>TID000022</td><td>CH022</td><td>706.07</td><td>Electronics</td><td>Chicago</td><td>2025-01-01T21:00:00.000Z</td><td>0</td></tr><tr><td>TID000023</td><td>CH023</td><td>1467.8</td><td>Restaurant</td><td>Los Angeles</td><td>2025-01-01T22:00:00.000Z</td><td>0</td></tr><tr><td>TID000024</td><td>CH024</td><td>1838.15</td><td>Retail</td><td>New York</td><td>2025-01-01T23:00:00.000Z</td><td>1</td></tr><tr><td>TID000025</td><td>CH025</td><td>2285.79</td><td>Restaurant</td><td>Chicago</td><td>2025-01-02T00:00:00.000Z</td><td>0</td></tr><tr><td>TID000026</td><td>CH026</td><td>3928.03</td><td>Grocery</td><td>New York</td><td>2025-01-02T01:00:00.000Z</td><td>0</td></tr><tr><td>TID000027</td><td>CH027</td><td>1006.37</td><td>Travel</td><td>New York</td><td>2025-01-02T02:00:00.000Z</td><td>0</td></tr><tr><td>TID000028</td><td>CH028</td><td>2576.03</td><td>Electronics</td><td>Phoenix</td><td>2025-01-02T03 ...
# root
#  |-- Transaction ID: string (nullable = true)
#  |-- Cardholder ID: string (nullable = true)
#  |-- Transaction Amount: double (nullable = true)
#  |-- Merchant Type: string (nullable = true)
#  |-- Location: string (nullable = true)
#  |-- Time of Transaction: timestamp (nullable = true)
#  |-- Is Fraud: long (nullable = true)

# %%
print(f"Total Transactions: {fraud_df.count()}")
print(f"Total Columns: {len(fraud_df.columns)}")
# Out:
# Total Transactions: 1000
# Total Columns: 7

# %%
from pyspark.sql.functions import col, sum

null_counts = fraud_df.select([
    sum(col(c).isNull().cast("int")).alias(c) for c in fraud_df.columns
])
display(null_counts)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Transaction ID</th><th>Cardholder ID</th><th>Transaction Amount</th><th>Merchant Type</th><th>Location</th><th>Time of Transaction</th><th>Is Fraud</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
class_dist = spark.sql("""
SELECT 
  `Is Fraud` AS Class,
  COUNT(*) AS Transaction_Count,
  ROUND((COUNT(*) * 100) / (SELECT COUNT(*) FROM credit_card_data), 2) AS Percentage
FROM credit_card_data
GROUP BY `Is Fraud`
ORDER BY `Is Fraud`
""")

display(class_dist)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Class</th><th>Transaction_Count</th><th>Percentage</th></tr></thead><tbody><tr><td>0</td><td>941</td><td>94.1</td></tr><tr><td>1</td><td>59</td><td>5.9</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
amount_stats = spark.sql("""
SELECT 
  `Is Fraud` AS Class,
  ROUND(AVG(`Transaction Amount`), 2) AS Avg_Amount,
  ROUND(MAX(`Transaction Amount`), 2) AS Max_Amount,
  ROUND(MIN(`Transaction Amount`), 2) AS Min_Amount,
  ROUND(STDDEV(`Transaction Amount`), 2) AS Std_Amount
FROM credit_card_data
GROUP BY `Is Fraud`
ORDER BY `Is Fraud`
""")

display(amount_stats)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Class</th><th>Avg_Amount</th><th>Max_Amount</th><th>Min_Amount</th><th>Std_Amount</th></tr></thead><tbody><tr><td>0</td><td>2448.25</td><td>4998.59</td><td>33.11</td><td>1456.56</td></tr><tr><td>1</td><td>2585.98</td><td>4849.85</td><td>92.77</td><td>1483.46</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import col, hour, sum

time_analysis = fraud_df.withColumn(
    "Hour",
    hour(col("Time of Transaction"))
)

time_summary = time_analysis.groupBy("Hour").agg(
    sum((col("Is Fraud") == 1).cast("int")).alias("Fraud_Count"),
    sum((col("Is Fraud") == 0).cast("int")).alias("Non_Fraud_Count")
).orderBy("Hour")

display(time_summary)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Hour</th><th>Fraud_Count</th><th>Non_Fraud_Count</th></tr></thead><tbody><tr><td>0</td><td>2</td><td>40</td></tr><tr><td>1</td><td>2</td><td>40</td></tr><tr><td>2</td><td>2</td><td>40</td></tr><tr><td>3</td><td>1</td><td>41</td></tr><tr><td>4</td><td>4</td><td>38</td></tr><tr><td>5</td><td>3</td><td>39</td></tr><tr><td>6</td><td>1</td><td>41</td></tr><tr><td>7</td><td>1</td><td>41</td></tr><tr><td>8</td><td>6</td><td>36</td></tr><tr><td>9</td><td>1</td><td>41</td></tr><tr><td>10</td><td>3</td><td>39</td></tr><tr><td>11</td><td>2</td><td>40</td></tr><tr><td>12</td><td>6</td><td>36</td></tr><tr><td>13</td><td>2</td><td>40</td></tr><tr><td>14</td><td>2</td><td>40</td></tr><tr><td>15</td><td>1</td><td>41</td></tr><tr><td>16</td><td>5</td><td>36</td></tr><tr><td>17</td><td>2</td><td>39</td></tr><tr><td>18</td><td>2</td><td>39</td></tr><tr><td>19</td><td>2</td><td>39</td></tr><tr><td>20</td><td>0</td><td>41</td></tr><tr><td>21</td><td>1</td><td>40</td></tr><tr><td>22</td><td>5</td><td>36</td></tr><tr><td>23</td><td>3</td><td>38</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
feature_compare = spark.sql("""
SELECT 
  ROUND(AVG(`Is Fraud`), 4) AS Avg_Is_Fraud,
  `Is Fraud`
FROM credit_card_data
GROUP BY `Is Fraud`
""")
display(feature_compare)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Avg_Is_Fraud</th><th>Is Fraud</th></tr></thead><tbody><tr><td>0.0</td><td>0</td></tr><tr><td>1.0</td><td>1</td></tr></tbody></table></div>

# %%
fraud_summary = spark.sql("""
SELECT 
  `Is Fraud` AS Fraud_Flag,
  COUNT(*) AS Transaction_Count,
  ROUND(AVG(`Transaction Amount`), 2) AS Avg_Amount,
  ROUND(SUM(`Transaction Amount`), 2) AS Total_Amount,
  ROUND(STDDEV(`Transaction Amount`), 2) AS Std_Amount
FROM credit_card_data
GROUP BY `Is Fraud`
""")

display(fraud_summary)

fraud_summary.write.mode("overwrite").saveAsTable("workspace.default.fraud_summary")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Fraud_Flag</th><th>Transaction_Count</th><th>Avg_Amount</th><th>Total_Amount</th><th>Std_Amount</th></tr></thead><tbody><tr><td>0</td><td>941</td><td>2448.25</td><td>2303807.73</td><td>1456.56</td></tr><tr><td>1</td><td>59</td><td>2585.98</td><td>152572.58</td><td>1483.46</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import when, col

fraud_scored = fraud_df.withColumn(
    "Fraud_Risk_Score",
    when(
        (col("Transaction Amount") > 2000) & (col("Merchant Type") == "Online"), 0.9
    ).when(
        (col("Transaction Amount") > 1000) & (col("Merchant Type") == "Retail"), 0.7
    ).when(
        col("Transaction Amount") > 500, 0.5
    ).otherwise(0.1)
)

display(
    fraud_scored.select(
        "Transaction Amount", "Merchant Type", "Fraud_Risk_Score", "Is Fraud"
    ).limit(10)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Transaction Amount</th><th>Merchant Type</th><th>Fraud_Risk_Score</th><th>Is Fraud</th></tr></thead><tbody><tr><td>1878.96</td><td>Travel</td><td>0.5</td><td>0</td></tr><tr><td>4754.06</td><td>Travel</td><td>0.5</td><td>0</td></tr><tr><td>3662.65</td><td>Electronics</td><td>0.5</td><td>0</td></tr><tr><td>2997.31</td><td>Grocery</td><td>0.5</td><td>0</td></tr><tr><td>788.53</td><td>Grocery</td><td>0.5</td><td>0</td></tr><tr><td>788.41</td><td>Travel</td><td>0.5</td><td>0</td></tr><tr><td>299.84</td><td>Electronics</td><td>0.1</td><td>0</td></tr><tr><td>4332.22</td><td>Grocery</td><td>0.5</td><td>0</td></tr><tr><td>3009.56</td><td>Travel</td><td>0.5</td><td>0</td></tr><tr><td>3543.28</td><td>Retail</td><td>0.7</td><td>0</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
